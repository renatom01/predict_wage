# %%
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline

# %%
AV = AutoViz_Class()
df_av = AV.AutoViz('/Users/renatomelo/Desktop/Lighthouse /Lighthouse2/wage_train.csv')
# Out:
# Shape of your Data Set loaded: (32560, 16)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     16 Predictors classified...
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 21
# Time to run AutoViz = 31 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
